# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import seaborn as sns

# %%
df = pd.read_csv("D:\\Study\\UG Thesis\\Datasets\\ReibeiroDataset\\tweetsConvereted2017_toxicPerspectiveScore.csv")

# %%
df.head()
# Out:
#               user_id     screen_name            tweet_id  \
# 0          4746709454      just_jusss  911477065328631809
# 1          4746709454      just_jusss  911399501264384001
# 2          4746709454      just_jusss  911343372282900480
# 3  773711528398848000  CassandraCohan  923729371235586049
# 4  773711528398848000  CassandraCohan  923689995763843072
#
#                                           tweet_text  tweet_creation  \
# 0  Having a strict dad, if I ask to go out one we...    1.506159e+09
# 1  Lookin at all these couples like MBN🤧 but then...    1.506140e+09
# 2  Being a senior kinda sucks when most of your f...    1.506127e+09
# 3                          @periwinkledink So pretty    1.509076e+09
# 4  @readyforramos It’s 2017 we go to church and pray    1.509067e+09
#
#    tweet_fav  tweet_rt  rp_flag           rp_status       rp_user  ...  \
# 0        1.0       0.0    False                 NaN           NaN  ...
# ...

# %%
len(df)
# Out:
# 6610132

# %%
# Parse the dates in the NewDateFormat column and extract the week number
df["week"] = df["NewDateFormat"].apply(lambda x: datetime.strptime(x, "%Y-%m-%d %H:%M:%S").strftime("%U"))

# %%
df.head()
# Out:
#               user_id     screen_name            tweet_id  \
# 0          4746709454      just_jusss  911477065328631809
# 1          4746709454      just_jusss  911399501264384001
# 2          4746709454      just_jusss  911343372282900480
# 3  773711528398848000  CassandraCohan  923729371235586049
# 4  773711528398848000  CassandraCohan  923689995763843072
#
#                                           tweet_text  tweet_creation  \
# 0  Having a strict dad, if I ask to go out one we...    1.506159e+09
# 1  Lookin at all these couples like MBN🤧 but then...    1.506140e+09
# 2  Being a senior kinda sucks when most of your f...    1.506127e+09
# 3                          @periwinkledink So pretty    1.509076e+09
# 4  @readyforramos It’s 2017 we go to church and pray    1.509067e+09
#
#    tweet_fav  tweet_rt  rp_flag           rp_status       rp_user  ...  \
# 0        1.0       0.0    False                 NaN           NaN  ...
# ...

# %%
#lets check month wise distribution of tweets in 2017
print("tweet counts for each month\n")
# Jan
jan_count = df[(df['tweet_creation']>=1483228800) & (df['tweet_creation']<=1485907199)]
print("Jan - " + str(len(jan_count)))
#Feb
feb_count = df[(df['tweet_creation']>=1485907200) & (df['tweet_creation']<=1488326399)]
print("Feb - " + str(len(feb_count)))
#March
mar_count = df[(df['tweet_creation']>=1488326400) & (df['tweet_creation']<=1491004799)]
print("Mar - " + str(len(mar_count)))
# April
apr_count = df[(df['tweet_creation']>=1491004800) & (df['tweet_creation']<=1493596799)]
print("Apr - " + str(len(apr_count)))
# May
may_count = df[(df['tweet_creation']>=1493596800) & (df['tweet_creation']<=1496275199)]
print("May - " + str(len(may_count)))
# June
jun_count = df[(df['tweet_creation']>=1496275200) & (df['tweet_creation']<=1498867199)]
print("Jun - " + str(len(jun_count)))
# July
jul_count = df[(df['tweet_creation']>=1498867200) & (df['tweet_creation']<=1501545599)]
print("Jul - " + str(len(jul_count)))
#Aug
aug_count = df[(df['tweet_creation']>=1501545600) & (df['tweet_creation']<=1504223999)]
print("Aug - " + str(len(aug_count)))
#Sep
sep_count = df[(df['tweet_creation']>=1504224000) & (df['tweet_creation']<=1506815999)]
print("Sep - " + str(len(sep_count)))
#Oct
oct_count = df[(df['tweet_creation']>=1506816000) & (df['tweet_creation']<=1509494399)]
print("Oct - " + str(len(oct_count)))
#Nov
nov_count = df[(df['tweet_creation']>=1509494400) & (df['tweet_creation']<=1512086399)]
print("Nov - " + str(len(nov_count)))
#dec
dec_count = df[(df['tweet_creation']>=1512086400) & (df['tweet_creation']<=1514764799)]
print("Dec - " + str(len(dec_count)))
# Out:
# tweet counts for each month
#
# Jan - 35984
# Feb - 43348
# Mar - 63439
# Apr - 72937
# May - 105780
# Jun - 149377
# Jul - 213742
# Aug - 377880
# Sep - 868038
# Oct - 4679607
# Nov - 0
# Dec - 0

# %%
total_count = len(jan_count) + len(feb_count) + len(mar_count) + len(apr_count) + len(may_count) + len(jun_count) + len(jul_count) + len(aug_count) + len(sep_count) + len(oct_count) + len(nov_count) + len(dec_count)
total_count
# Out:
# 6610132

# %%
#count users
countUsers = df['user_id'].unique()
countUsers2 = df['screen_name'].unique()
print(countUsers.size)
print(countUsers2.size)
# Out:
# 59848
# 59848

# %%
#plot 1
column = df['Toxicity']
plt.hist(column, bins=10)

# Add a title and labels
plt.title('Histogram of Column Name')
plt.xlabel('Column Values')
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
groupDf = df[['screen_name', 'Toxicity', 'Severe Toxicity', 'week']]

# %%
groupDf1 = groupDf.groupby(['screen_name', 'week'])

# %%
groupDf1.head()
# Out:
#             screen_name  Toxicity  Severe Toxicity week
# 0            just_jusss  0.052305         0.002346   38
# 1            just_jusss  0.068171         0.003433   38
# 2            just_jusss  0.518691         0.023787   38
# 3        CassandraCohan  0.010681         0.002117   43
# 4        CassandraCohan  0.018975         0.001316   43
# ...                 ...       ...              ...  ...
# 6610095    s_malcolmson  0.009990         0.000734   43
# 6610096    s_malcolmson  0.009236         0.000911   43
# 6610097    s_malcolmson  0.008608         0.000811   43
# 6610098    s_malcolmson  0.020607         0.002518   43
# 6610099    s_malcolmson  0.012943         0.000696   43
#
# [1811651 rows x 4 columns]

# %%
print(groupDf1.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <module>
# ----> 1 print(groupDf1.columns.tolist())
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'columns'

# %%
groupDf1.loc[groupDf1['screen_name'] == '0000seapea808']

# %%
groupDf2 = groupDf.groupby(['screen_name', 'week']).mean()

# %%
groupDf2.head()

# %%
print(groupDf2.columns.tolist())

# %%
# Find a value in a pandas data frame based on loc
# groupDf2.loc[groupDf2['screen_name'] == 'just_jusss']

# %%
groupDf2 = groupDf2.sort_values(by=['week'])

# %%
groupDf2.head()

# %%
# df["week"] = df["week"].astype(float)

# # Check the shape of the screen_name, Toxicity, and week columns
# print(df["screen_name"].shape)
# print(df["Toxicity"].shape)
# print(df["week"].shape)

# %%
# # Create a scatter plot
# sns.scatterplot(x="screen_name", y="Toxicity", size="week", data=groupDf)

# # Add a title
# plt.title("Toxicity scores by user and week")

# # Show the plot
# plt.show()
