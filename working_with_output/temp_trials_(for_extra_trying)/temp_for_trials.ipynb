# %%
import matplotlib.pyplot as plt

# %%
A = [1, 2, 3, 4, 5]
B = [2, 4, 6, 8, 10]

# %%
plt.semilogy(A, B)
plt.xlabel("A")
plt.ylabel("B")
plt.title("Semilogarithmic plot of arrays A and B (excluding last element)")
plt.show()
