# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import seaborn as sns
# import warnings
# warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("D:\\Study\\UG Thesis\\Datasets\\ReibeiroDataset\\tweetsConvereted2017_toxicPerspectiveScore.csv")

# %%
df["week"] = df["NewDateFormat"].apply(lambda x: datetime.strptime(x, "%Y-%m-%d %H:%M:%S").strftime("%U"))
df["month"] = df["NewDateFormat"].apply(lambda x: datetime.strptime(x, "%Y-%m-%d %H:%M:%S").strftime("%m"))

# %%
df.head()
# Out:
#               user_id     screen_name            tweet_id  \
# 0          4746709454      just_jusss  911477065328631809
# 1          4746709454      just_jusss  911399501264384001
# 2          4746709454      just_jusss  911343372282900480
# 3  773711528398848000  CassandraCohan  923729371235586049
# 4  773711528398848000  CassandraCohan  923689995763843072
#
#                                           tweet_text  tweet_creation  \
# 0  Having a strict dad, if I ask to go out one we...    1.506159e+09
# 1  Lookin at all these couples like MBN🤧 but then...    1.506140e+09
# 2  Being a senior kinda sucks when most of your f...    1.506127e+09
# 3                          @periwinkledink So pretty    1.509076e+09
# 4  @readyforramos It’s 2017 we go to church and pray    1.509067e+09
#
#    tweet_fav  tweet_rt  rp_flag           rp_status       rp_user  ...  \
# 0        1.0       0.0    False                 NaN           NaN  ...
# 1        2.0       0.0    False                 NaN           NaN  ...
# 2        3.0       0.0    False                 NaN           NaN  ...
# 3        1.0       0.0     True  923705106264027136  3.434322e+09  ...
# 4        3.0       0.0     True  923689936406044673  2.633570e+09  ...
#
#    rt_user_id  rt_text  rt_creation rt_fav  rt_rt  Toxicity  Severe Toxicity  \
# 0         NaN      NaN          NaN    NaN    NaN  0.052305         0.002346
# 1         NaN      NaN          NaN    NaN    NaN  0.068171         0.003433
# 2         NaN      NaN          NaN    NaN    NaN  0.518691         0.023787
# 3         NaN      NaN          NaN    NaN    NaN  0.010681         0.002117
# 4         NaN      NaN          NaN    NaN    NaN  0.018975         0.001316
#
#          NewDateFormat  week  month
# 0  2017-09-23 09:27:21    38     09
# 1  2017-09-23 04:19:08    38     09
# 2  2017-09-23 00:36:06    38     09
# 3  2017-10-27 03:53:38    43     10
# 4  2017-10-27 01:17:10    43     10
#
# [5 rows x 29 columns]

# %%
groupDf = df[['user_id', 'Toxicity', 'qt_flag', 'rt_flag', 'week', 'month']]

# %%
unique_values_week = groupDf['week'].unique()
unique_values_month = groupDf['month'].unique()
unique_values_week.sort()
unique_values_month.sort()

# %% [markdown]
# # Plot 1
# ## Weighted Sum of toxicities summed up across all users per week
# xaxis - wk1 wk2 ... wk43
# yaxis - weighted sum

# %%
def weightedSumToxicityWeek(weekIn):
    weekDf = groupDf[groupDf['week'] == weekIn]
    weekDf['Toxicity'] = weekDf['Toxicity'] * 10
    weekDf['Toxicity'] = (weekDf['Toxicity'].apply(np.ceil)) / 10
    return weekDf['Toxicity'].sum().round(2)

# %%
plot1Arr = []
for i in unique_values_week:
    plot1Arr.append(weightedSumToxicityWeek(i))

# %%
plot1XAxis = unique_values_week
plot1YAxis = plot1Arr

# %%
plt.figure(figsize=(15,5))
plt.plot(plot1XAxis[:-1], plot1YAxis[:-1])
plt.xlabel("Week Number")
plt.ylabel("Weighted Sum of Toxicity for all Users ")
plt.title("Weighted Sum of toxicities summed up across all users per week")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.semilogy(plot1XAxis[:-1], plot1YAxis[:-1])
plt.xlabel("Week Number")
plt.ylabel("Weighted Sum of Toxicity for all Users ")
plt.title("Weighted Sum of toxicities summed up across all users per week")
plt.xticks(rotation=45)
plt.yticks(plot1YAxis[:-1])
# plt.yticks(fontsize=25)
# plt.ylim(np.min(plot1YAxis[:-1]), np.max(plot1YAxis[:-1]))
plt.show()

# %% [markdown]
# # Plot 2
# ## Weighted Sum of toxicities summed up across all users per month
# xaxis - mnth1 ... mnth10
# yaxis - weighted sum

# %%
def weightedSumToxicityMonth(monthIn):
    monthDf = groupDf[groupDf['month'] == monthIn]
    monthDf['Toxicity'] = monthDf['Toxicity'] * 10
    monthDf['Toxicity'] = (monthDf['Toxicity'].apply(np.ceil)) / 10
    return monthDf['Toxicity'].sum().round(2)

# %%
plot2Arr = []
for i in unique_values_month:
    plot2Arr.append(weightedSumToxicityMonth(i))

# %%
plot2XAxis = unique_values_month
plot2YAxis = plot2Arr

# %%
plt.plot(plot2XAxis,plot2YAxis)
plt.xlabel("Month Number")
plt.ylabel("Weighted Sum of Toxicity for all Users ")
plt.title("Weighted Sum of toxicities summed up across all users per month")
plt.show()
