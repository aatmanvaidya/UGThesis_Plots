# %%
#kaggle file

# %%
# !conda install -y gdown
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 22.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - gdown
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     filelock-3.9.0             |     pyhd8ed1ab_0          13 KB  conda-forge
#     gdown-4.6.3                |     pyhd8ed1ab_0          18 KB  conda-forge
#     openssl-1.1.1t             |       h0b41bf4_0         1.9 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   filelock           conda-forge/noarch::filelock-3.9.0-pyhd8ed1ab_0 None
# ...

# %%
# !gdown --id 163v2qHhC64Vcq5I0dxW28ZWSf27tK2lS
# !gdown --id 1wRmYDLkkOFY_EUYL_VyTO3AvZbyShlk9
# Out:
# /opt/conda/lib/python3.7/site-packages/gdown/cli.py:125: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=163v2qHhC64Vcq5I0dxW28ZWSf27tK2lS
# To: /kaggle/working/tweets_new.csv
# 100%|███████████████████████████████████████| 4.54G/4.54G [00:35<00:00, 128MB/s]

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("tweets_new.csv")

# %%
print(df.shape)
# Out:
# (19536787, 24)

# %%
df['rt_text'].isna().sum()
# Out:
# 12307785

# %%
convDf = df.dropna(subset=['rt_text'])

# %%
convDf['rt_text'].isna().sum()
# Out:
# 0

# %%
convDf.shape
# Out:
# (7229002, 24)

# %%
convDf.to_csv("tweets_retweetFile.csv",index = False)

# %%
convDf.head()
# Out:
#               user_id     screen_name            tweet_id tweet_text  \
# 2  850859913244852224  NationalismXXI  919367819694927872        NaN
# 3  850859913244852224  NationalismXXI  919366633512226816        NaN
# 4  850859913244852224  NationalismXXI  919365144697860096        NaN
# 5  850859913244852224  NationalismXXI  919361129226399745        NaN
# 6  850859913244852224  NationalismXXI  919357843345674240        NaN
#
#    tweet_creation  tweet_fav  tweet_rt  rp_flag rp_status  rp_user  ...  \
# 2    1.508037e+09          0       777    False       NaN      NaN  ...
# 3    1.508040e+09          0        63    False       NaN      NaN  ...
# 4    1.508040e+09          0       105    False       NaN      NaN  ...
# 5    1.508039e+09          0      1238    False       NaN      NaN  ...
# 6    1.508038e+09          0       111    False       NaN      NaN  ...
#
#    qt_creation  qt_fav  qt_rt rt_flag  rt_status_id    rt_user_id  \
# ...

# %%
convDf['rt_flag'].unique()
# Out:
# array([ True])
