# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("D:\\Study\\UG Thesis\\Datasets\\Dataset Breakdown\\data_inputFile2.csv")

# %%
df1.head()
# Out:
#    user_id    screen_name            tweet_id  \
# 0   755504  alexandraerin  923637675168616448
# 1   755504  alexandraerin  923637320494043144
# 2   755504  alexandraerin  923637140604547073
# 3   755504  alexandraerin  923637018927751168
# 4   755504  alexandraerin  923636920218943488
#
#                                           tweet_text  tweet_creation  \
# 0  @AnaMardoll These are issues within a manuscri...    1.509055e+09
# 1  @KHLazarus @AnaMardoll Much worse than either ...    1.509054e+09
# 2  @AnaMardoll "Oh, my characterization is gettin...    1.509054e+09
# 3  @AnaMardoll "Oh, this detail on page 273 comes...    1.509054e+09
# 4  @AnaMardoll "Oh, this character is doing this ...    1.509054e+09
#
#    tweet_fav  tweet_rt  rp_flag           rp_status      rp_user  ...  \
# 0       18.0       2.0     True  923637140604547073     755504.0  ...
# 1        3.0       1.0     True  923636941274443778  630276647.0  ...
# ...

# %%
len(df1)
# Out:
# 746646
